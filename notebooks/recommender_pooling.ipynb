# %% [markdown]
# # Notebook where to build the Tensorflow Recommender Model (Pooling)

# %% [markdown]
# ## Data Prep

# %%
import pandas as pd

customers_csv_path = '/data/processed/customers_df.csv'
customers_df = pd.read_csv(customers_csv_path)
customers_df.head(3)
# Out:
#                                          customer_id  Active  \
# 0  00000dbacae5abe5e23885899a1fa44253a17956c6d1c3...     0.0
# 1  0000423b00ade91418cceaf3b26c6af3dd342b51fd051e...     0.0
# 2  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...     0.0
#
#   club_member_status fashion_news_frequency  age postal_code  \
# 0             ACTIVE                   NONE   49      974 04
# 1             ACTIVE                   NONE   25     WF1 5EY
# 2             ACTIVE                   NONE   24       75008
#
#                                   purchased_articles  favorite_sales_channel
# 0  [625548001, 176209023, 627759010, 697138006, 5...                     2.0
# 1  [583558001, 639677008, 640244003, 521269001, 6...                     2.0
# 2  [663713001, 541518023, 663713001, 578020002, 7...                     2.0

# %%
customers_df.shape
# Out:
# (1371980, 8)

# %%
customers_df.columns
# Out:
# Index(['customer_id', 'Active', 'club_member_status', 'fashion_news_frequency',
#        'age', 'postal_code', 'purchased_articles', 'favorite_sales_channel'],
#       dtype='object')

# %%
stores_csv = '/data/processed/stores_df.csv'
stores_df = pd.read_csv(stores_csv)
stores_df.drop(columns=['Unnamed: 0'], inplace=True)
stores_df.head(3)
# Out:
#   storeCode storeClass                 name          phone       city  \
# 0    AE0122        Red  Mirdiff city center  +971-42316646      Dubai
# 1    AE0149   Flagship           Dubai Mall  +971-44190346      Dubai
# 2    AE0209       Blue        Al Markaziyah  +971-26120870  Abu Dhabi
#
#                 country countryCode  longitude   latitude  timeZoneIndex  ...  \
# 0  United Arab Emirates          AE  55.424840  25.226280          165.0  ...
# 1  United Arab Emirates          AE  55.278446  25.197506          165.0  ...
# 2  United Arab Emirates          AE  54.357462  24.487245          165.0  ...
#
#   Wed_open_hours Thu_open_hours Fri_open_hours Sat_open_hours Sun_open_hours  \
# 0    10:00-22:00    10:00-23:55    10:00-23:55    10:00-23:55    10:00-22:00
# 1    10:00-23:00    10:00-23:55    10:00-23:55    10:00-23:00    10:00-23:00
# 2    10:00-22:00    10:00-23:00    10:00-23:00    10:00-22:00    10:00-22:00
#
#            streetName1                     streetName2      state  \
# 0  Mirdiff city center  Sheikh Mohammad Bin Zayed Road      Dubai
# 1           Dubai Mall               Sheikh Zayed Road      Dubai
# 2        Al Markaziyah         World Trade Center Mall  Abu Dhabi
#
#                                       address_string postal_code
# 0  Mirdiff city center;Sheikh Mohammad Bin Zayed ...         NaN
# 1     Dubai Mall;Sheikh Zayed Road;Dubai;Dubai;Dubai         NaN
# 2  Al Markaziyah;World Trade Center Mall;123;Abu ...         NaN
#
# [3 rows x 22 columns]

# %%
stores_df.shape
# Out:
# (4290, 22)

# %%
stores_df.isna().sum()
# Out:
# storeCode            0
# storeClass           3
# name                 2
# phone              152
# city                 0
# country              0
# countryCode          0
# longitude            0
# latitude             0
# timeZoneIndex        3
# Mon_open_hours      34
# Tue_open_hours      34
# Wed_open_hours      34
# Thu_open_hours      34
# Fri_open_hours      34
# Sat_open_hours      34
# Sun_open_hours    1144
# streetName1          0
# streetName2       2465
# state             1859
# address_string       0
# postal_code        286
# dtype: int64

# %%
stores_loc = stores_df[['country', 'state', 'postal_code']]
stores_loc.dropna(inplace=True)
stores_loc.reset_index(drop=True, inplace=True)
stores_loc.head(3)
# Out:
# /tmp/ipykernel_32084/703925720.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stores_loc.dropna(inplace=True)
#    country       state postal_code
# 0  Austria    Salzburg        5020
# 1  Austria       Tirol        6130
# 2  Austria  Steiermark        8051

# %%
customers_data = pd.merge(customers_df, stores_loc, on='postal_code')
customers_data.head(3)
# Out:
#                                          customer_id  Active  \
# 0  00005ca1c9ed5f5146b52ac8639a40ca9d57aeff4d1bd2...     0.0
# 1  00006413d8573cd20ed7128e53b7b13819fe5cfc2d801f...     1.0
# 2  000064249685c11552da43ef22a5030f35a147f723d5b0...     0.0
#
#   club_member_status fashion_news_frequency  age postal_code  \
# 0             ACTIVE                   NONE   54       13290
# 1             ACTIVE              Regularly   52       29221
# 2          LEFT CLUB                Monthly   36      450018
#
#                                   purchased_articles  favorite_sales_channel  \
# 0                             [742079001, 732413001]                     2.0
# 1  [634249005, 677049001, 698286003, 707704003, 3...                     2.0
# 2                  [738133005, 680265002, 740962001]                     2.0
#
#           country           state
# 0             USA        New York
# 1         Germany   Niedersachsen
# 2  Mainland China  Henan Province

# %%
customers_data['country'].unique()
# Out:
# array(['USA', 'Germany', 'Mainland China', 'Russian Federation', 'Italy',
#        'Poland', 'Australia', 'Belgium', 'Canada', 'South Africa',
#        'Spain', 'Mexico', 'Austria', 'New Zealand', 'Switzerland',
#        'Turkey', 'Portugal', 'Colombia', 'Ukraine', 'Peru', 'Luxembourg',
#        'Kazakhstan'], dtype=object)

# %%
customers_data['country'].value_counts()
# Out:
# country
# USA                   195878
# Mainland China        142121
# Germany               138340
# Poland                 65957
# Italy                  58248
# Spain                  50748
# Russian Federation     41065
# Canada                 33349
# Austria                28743
# Switzerland            23617
# Belgium                22683
# Mexico                 20698
# Turkey                 18936
# Australia              13532
# Portugal                9989
# South Africa            5593
# Colombia                3854
# Ukraine                 3385
# New Zealand             3078
# Luxembourg              2646
# Kazakhstan              1122
# Peru                     361
# Name: count, dtype: int64

# %%
customers_data = customers_data.loc[customers_data['country'].isin(['New Zealand'])]
customers_data.reset_index(drop=True, inplace=True)
customers_data.head(3)
# Out:
#                                          customer_id  Active  \
# 0  0005baed366933727a0ee8407c56e5f065fd5b09c71478...     0.0
# 1  001c9cf3869156c0f7691ac577914b5c38f56ba33728c8...     1.0
# 2  0023e4a27084d4e13bbc877e007b2a1ac115a7edde6e87...     0.0
#
#   club_member_status fashion_news_frequency  age postal_code  \
# 0             ACTIVE                   NONE   39        8041
# 1             ACTIVE              Regularly   36        5010
# 2             ACTIVE                   NONE   19        1023
#
#        purchased_articles  favorite_sales_channel      country         state
# 0             [498620002]                     2.0  New Zealand  South Island
# 1  [705966002, 796210008]                     2.0  New Zealand  North Island
# 2  [741220002, 706443001]                     2.0  New Zealand  North Island

# %%
customers_data.shape
# Out:
# (3078, 10)

# %%
customers_data['club_member_status'].unique()
# Out:
# array(['ACTIVE', 'PRE-CREATE', 'LEFT CLUB'], dtype=object)

# %%
customers_data['fashion_news_frequency'].unique()
# Out:
# array(['NONE', 'Regularly', 'Monthly'], dtype=object)

# %%
customers_data['favorite_sales_channel'].unique()
# Out:
# array([ 2., nan,  1.])

# %%
customers_data.fillna({'favorite_sales_channel': 'UNKNOWN'}, inplace=True)
customers_data['favorite_sales_channel'] = customers_data['favorite_sales_channel'].astype(str)

# %%
customers_data.isna().sum()
# Out:
# customer_id               0
# Active                    0
# club_member_status        0
# fashion_news_frequency    0
# age                       0
# postal_code               0
# purchased_articles        0
# favorite_sales_channel    0
# country                   0
# state                     0
# dtype: int64

# %%
import ast

customers_data['purchased_articles'] = customers_data['purchased_articles'].apply(lambda x: (ast.literal_eval(x)))
customers_data['nb_past_purchases'] = customers_data['purchased_articles'].apply(lambda x: len(x))
customers_data['nb_past_purchases'].mean().round(0)
# Out:
# np.float64(23.0)

# %%
from itertools import chain

all_articles = set(chain.from_iterable(customers_data["purchased_articles"]))

# %%
len(all_articles)
# Out:
# 27111

# %%
articles_csv = '/data/processed/articles_df.csv'
articles_df = pd.read_csv(articles_csv)
articles_df.columns
# Out:
# Index(['article_id', 'prod_name', 'product_type_name', 'product_group_name',
#        'department_name', 'index_name', 'section_name', 'detail_desc'],
#       dtype='object')

# %%
articles_df.head(3)
# Out:
#    article_id      prod_name product_type_name  product_group_name  \
# 0   108775015      Strap top          Vest top  Garment Upper body
# 1   108775044      Strap top          Vest top  Garment Upper body
# 2   108775051  Strap top (1)          Vest top  Garment Upper body
#
#   department_name  index_name            section_name  \
# 0    Jersey Basic  Ladieswear  Womens Everyday Basics
# 1    Jersey Basic  Ladieswear  Womens Everyday Basics
# 2    Jersey Basic  Ladieswear  Womens Everyday Basics
#
#                                detail_desc
# 0  Jersey top with narrow shoulder straps.
# 1  Jersey top with narrow shoulder straps.
# 2  Jersey top with narrow shoulder straps.

# %%
from sklearn.preprocessing import MinMaxScaler
import joblib

scaler = MinMaxScaler()
scaler.fit(customers_data[["age"]])
customers_data["age_scaled"] = scaler.transform(customers_data[["age"]])

joblib.dump(scaler, "/data/scalers/age_scaler.pkl")
# Out:
# ['/data/scalers/age_scaler.pkl']

# %%
customers_data.head(3)
# Out:
#                                          customer_id  Active  \
# 0  0005baed366933727a0ee8407c56e5f065fd5b09c71478...     0.0
# 1  001c9cf3869156c0f7691ac577914b5c38f56ba33728c8...     1.0
# 2  0023e4a27084d4e13bbc877e007b2a1ac115a7edde6e87...     0.0
#
#   club_member_status fashion_news_frequency  age postal_code  \
# 0             ACTIVE                   NONE   39        8041
# 1             ACTIVE              Regularly   36        5010
# 2             ACTIVE                   NONE   19        1023
#
#        purchased_articles favorite_sales_channel      country         state  \
# 0             [498620002]                    2.0  New Zealand  South Island
# 1  [705966002, 796210008]                    2.0  New Zealand  North Island
# 2  [741220002, 706443001]                    2.0  New Zealand  North Island
#
#    nb_past_purchases  age_scaled
# 0                  1    0.343750
# 1                  2    0.296875
# 2                  2    0.031250

# %% [markdown]
# ## Modeling

# %% [markdown]
# ## Target

# %% [markdown]
# We treat each purchased article as a positive implicit interaction. The target is to retrieve the right article for a given customer, so we build a row per (customer_id, article_id) pair, then join in customer and item features.

# %%
import ast

def _ensure_list(x):
    if isinstance(x, list):
        return x
    if pd.isna(x):
        return []
    try:
        return ast.literal_eval(x)
    except (ValueError, SyntaxError):
        s = str(x).strip()
        if s.startswith("[") and s.endswith("]"):
            s = s[1:-1]
        return [i.strip().strip("'").strip("'") for i in s.split(",") if i.strip()]

MAX_HISTORY = 50

def _pad_or_truncate(items, max_len=MAX_HISTORY):
    items = list(items)[:max_len]
    if len(items) < max_len:
        items = items + [""] * (max_len - len(items))
    return items

customers_data["purchased_articles_list"] = customers_data["purchased_articles"].apply(_ensure_list)
customers_data["history_article_ids"] = customers_data["purchased_articles_list"].apply(_pad_or_truncate)

interactions = customers_data[["customer_id", "purchased_articles_list"]].explode("purchased_articles_list")
interactions = interactions.dropna(subset=["purchased_articles_list"])
interactions = interactions[interactions["purchased_articles_list"] != ""]
interactions = interactions.rename(columns={"purchased_articles_list": "article_id"})

# Bring in customer and article features used by the model.
customer_features = customers_data[
    [
        "customer_id",
        "age_scaled",
        "club_member_status",
        "fashion_news_frequency",
        "favorite_sales_channel",
        "history_article_ids",
    ]
].copy()

articles_features = articles_df[
    ["article_id", "product_type_name", "section_name", "product_group_name", "detail_desc"]
].copy()

# Normalize types and fill missing text fields.
customer_features["customer_id"] = customer_features["customer_id"].astype(str)
articles_features["article_id"] = articles_features["article_id"].astype(str)

for col in ["club_member_status", "fashion_news_frequency", "favorite_sales_channel"]:
    customer_features[col] = customer_features[col].astype(str).fillna("unknown")

for col in ["product_type_name", "section_name", "product_group_name", "detail_desc"]:
    articles_features[col] = articles_features[col].astype(str).fillna("unknown")

interactions["customer_id"] = interactions["customer_id"].astype(str)
interactions["article_id"] = interactions["article_id"].astype(str)

interactions = interactions.merge(customer_features, on="customer_id", how="left")
interactions = interactions.merge(articles_features, on="article_id", how="left")

interactions.head(3)
# Out:
#                                          customer_id article_id  age_scaled  \
# 0  0005baed366933727a0ee8407c56e5f065fd5b09c71478...  498620002    0.343750
# 1  001c9cf3869156c0f7691ac577914b5c38f56ba33728c8...  705966002    0.296875
# 2  001c9cf3869156c0f7691ac577914b5c38f56ba33728c8...  796210008    0.296875
#
#   club_member_status fashion_news_frequency favorite_sales_channel  \
# 0             ACTIVE                   NONE                    2.0
# 1             ACTIVE              Regularly                    2.0
# 2             ACTIVE              Regularly                    2.0
#
#                                  history_article_ids product_type_name  \
# 0  [498620002, , , , , , , , , , , , , , , , , , ...            Jacket
# 1  [705966002, 796210008, , , , , , , , , , , , ,...           Sweater
# 2  [705966002, 796210008, , , , , , , , , , , , ,...          Trousers
#
#                  section_name  product_group_name  \
# 0            Ladies H&M Sport  Garment Upper body
# 1            Womens Tailoring  Garment Upper body
# 2  Womens Everyday Collection  Garment Lower body
#
#                                          detail_desc
# 0  Outdoor jacket with light padding front and ba...
# 1  Long-sleeved jumper in a soft, fine-knit visco...
# 2  Trousers in superstretch twill with a high wai...

# %% [markdown]
# ### Create Model

# %% [markdown]
# We build a two-tower retrieval model: a customer tower encodes user features, an article tower encodes item features, and the retrieval task learns to score purchased items higher than other candidates.

# %%
import os

os.environ["TF_USE_LEGACY_KERAS"] = "1"

# %%
import numpy as np
import tensorflow as tf
import tensorflow_recommenders as tfrs

tf.random.set_seed(42)

# Build train/test split.
interactions = interactions.sample(frac=1.0, random_state=42).reset_index(drop=True)
train_size = int(0.8 * len(interactions))
train_df = interactions.iloc[:train_size]
test_df = interactions.iloc[train_size:]

# Build tf.data datasets.
def df_to_dataset(df):
    history_array = np.stack(df["history_article_ids"].values)
    return tf.data.Dataset.from_tensor_slices({
        "customer_id": df["customer_id"].astype(str).values,
        "age_scaled": df["age_scaled"].astype("float32").values,
        "club_member_status": df["club_member_status"].astype(str).fillna("unknown").values,
        "fashion_news_frequency": df["fashion_news_frequency"].astype(str).fillna("unknown").values,
        "favorite_sales_channel": df["favorite_sales_channel"].astype(str).fillna("unknown").values,
        "history_article_ids": history_array,
        "article_id": df["article_id"].astype(str).values,
        "product_type_name": df["product_type_name"].astype(str).fillna("unknown").values,
        "section_name": df["section_name"].astype(str).fillna("unknown").values,
        "product_group_name": df["product_group_name"].astype(str).fillna("unknown").values,
        "detail_desc": df["detail_desc"].astype(str).fillna("unknown").values,
    })

BATCH_SIZE = 1024
train_ds = df_to_dataset(train_df).shuffle(100_000, seed=42).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
test_ds = df_to_dataset(test_df).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
# Out:
# 2026-01-23 10:58:52.228088: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1769165936.901762   32084 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13713 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3080 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
# Vocabularies.
unique_customer_ids = customer_features["customer_id"].unique()
unique_article_ids = articles_features["article_id"].unique()
unique_club_status = customer_features["club_member_status"].unique()
unique_news_freq = customer_features["fashion_news_frequency"].unique()
unique_sales_channel = customer_features["favorite_sales_channel"].unique()

unique_product_type = articles_features["product_type_name"].unique()
unique_section = articles_features["section_name"].unique()
unique_product_group = articles_features["product_group_name"].unique()

# Text vectorizer for descriptions.
desc_vectorizer = tf.keras.layers.TextVectorization(
    max_tokens=10_000,
    output_mode="int",
    output_sequence_length=50,
)
desc_vectorizer.adapt(articles_features["detail_desc"].values)

# Shared item lookup/embedding for item ids and history pooling.
article_lookup = tf.keras.layers.StringLookup(
    vocabulary=unique_article_ids, mask_token=""
)
article_embedding = tf.keras.layers.Embedding(
    article_lookup.vocabulary_size(), 64, mask_zero=True
)

# %%
class CustomerModel(tf.keras.Model):
    def __init__(self, article_lookup_layer, article_embedding_layer):
        super().__init__()
        self.customer_lookup = tf.keras.layers.StringLookup(
            vocabulary=unique_customer_ids, mask_token=None
        )
        self.customer_embedding = tf.keras.layers.Embedding(
            self.customer_lookup.vocabulary_size(), 64
        )
        self.club_lookup = tf.keras.layers.StringLookup(
            vocabulary=unique_club_status, mask_token=None
        )
        self.club_embedding = tf.keras.layers.Embedding(
            self.club_lookup.vocabulary_size(), 32
        )
        self.news_lookup = tf.keras.layers.StringLookup(
            vocabulary=unique_news_freq, mask_token=None
        )
        self.news_embedding = tf.keras.layers.Embedding(
            self.news_lookup.vocabulary_size(), 8
        )
        self.sales_lookup = tf.keras.layers.StringLookup(
            vocabulary=unique_sales_channel, mask_token=None
        )
        self.sales_embedding = tf.keras.layers.Embedding(
            self.sales_lookup.vocabulary_size(), 8
        )
        self.history_lookup = article_lookup_layer
        self.history_embedding = article_embedding_layer
        self.history_pool = tf.keras.layers.GlobalAveragePooling1D()
        self.mlp = tf.keras.Sequential([
            tf.keras.layers.Dense(64, activation="relu"),
            tf.keras.layers.Dropout(0.2),
            tf.keras.layers.Dense(32),
        ])

    def call(self, features):
        history_ids = self.history_lookup(features["history_article_ids"])
        history_emb = self.history_embedding(history_ids)
        history_vec = self.history_pool(history_emb)

        x = tf.concat(
            [
                self.customer_embedding(self.customer_lookup(features["customer_id"])),
                self.club_embedding(self.club_lookup(features["club_member_status"])),
                self.news_embedding(self.news_lookup(features["fashion_news_frequency"])),
                self.sales_embedding(self.sales_lookup(features["favorite_sales_channel"])),
                tf.expand_dims(features["age_scaled"], -1),
                history_vec,
            ],
            axis=1,
        )
        return self.mlp(x)

class ArticleModel(tf.keras.Model):
    def __init__(self, article_lookup_layer, article_embedding_layer):
        super().__init__()
        self.article_lookup = article_lookup_layer
        self.article_embedding = article_embedding_layer

        self.product_type_lookup = tf.keras.layers.StringLookup(
            vocabulary=unique_product_type, mask_token=None
        )
        self.product_type_embedding = tf.keras.layers.Embedding(
            self.product_type_lookup.vocabulary_size(), 32
        )

        self.section_lookup = tf.keras.layers.StringLookup(
            vocabulary=unique_section, mask_token=None
        )
        self.section_embedding = tf.keras.layers.Embedding(
            self.section_lookup.vocabulary_size(), 8
        )

        self.product_group_lookup = tf.keras.layers.StringLookup(
            vocabulary=unique_product_group, mask_token=None
        )
        self.product_group_embedding = tf.keras.layers.Embedding(
            self.product_group_lookup.vocabulary_size(), 8
        )

        self.desc_encoder = tf.keras.Sequential(
            [
                desc_vectorizer,
                tf.keras.layers.Embedding(desc_vectorizer.vocabulary_size(), 32),
                tf.keras.layers.GlobalAveragePooling1D(),
            ]
        )
        self.mlp = tf.keras.Sequential([
            tf.keras.layers.Dense(64, activation="relu"),
            tf.keras.layers.Dropout(0.2),
            tf.keras.layers.Dense(32),
        ])

    def call(self, features):
        x = tf.concat(
            [
                self.article_embedding(self.article_lookup(features["article_id"])),
                self.product_type_embedding(self.product_type_lookup(features["product_type_name"])),
                self.section_embedding(self.section_lookup(features["section_name"])),
                self.product_group_embedding(self.product_group_lookup(features["product_group_name"])),
                self.desc_encoder(features["detail_desc"]),
            ],
            axis=1,
        )
        return self.mlp(x)

# Build candidate dataset for evaluation.
candidate_ds = tf.data.Dataset.from_tensor_slices(
    {
        "article_id": articles_features["article_id"].values,
        "product_type_name": articles_features["product_type_name"].values,
        "section_name": articles_features["section_name"].values,
        "product_group_name": articles_features["product_group_name"].values,
        "detail_desc": articles_features["detail_desc"].values,
    }
).batch(BATCH_SIZE)

class TwoTowerModel(tfrs.Model):
    def __init__(self, customer_model, article_model):
        super().__init__()
        self.customer_model = customer_model
        self.article_model = article_model
        self.task = tfrs.tasks.Retrieval(
            metrics=tfrs.metrics.FactorizedTopK(
                candidates=candidate_ds.map(article_model)
            )
        )

    def compute_loss(self, features, training=False):
        user_embeddings = self.customer_model(features)
        item_embeddings = self.article_model(features)
        return self.task(user_embeddings, item_embeddings)

# %%
import datetime

log_dir = os.path.join("/data/models/logs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))

#checkpoint_path = "/data/models/checkpoints/fashion_model_epoch_{epoch:02d}.weights.h5"
checkpoint_path = "/data/models/checkpoints/pooling_model_best_v2.weights.h5"

monitor_metric = "val_factorized_top_k/top_10_categorical_accuracy"

callbacks = [
    tf.keras.callbacks.EarlyStopping(
        monitor=monitor_metric,
        patience=8,
        mode="max",
        restore_best_weights=True,
        verbose=1,
    ),

    tf.keras.callbacks.ReduceLROnPlateau(
        monitor=monitor_metric,
        mode="max",
        factor=0.1,
        patience=3,
        min_lr=1e-4,
        cooldown=1,
        verbose=1,
    ),

    tf.keras.callbacks.TensorBoard(
        log_dir=log_dir,
        histogram_freq=0,
        write_images=False,
        write_graph=True,
        update_freq="epoch",
    ),

    tf.keras.callbacks.ModelCheckpoint(
        filepath=checkpoint_path,
        monitor=monitor_metric,
        mode="max",
        save_weights_only=True,
        #save_freq="epoch",
        save_best_only=True,
        verbose=1,
    ),
    
    tf.keras.callbacks.CSVLogger(
        os.path.join(log_dir, "training.csv")
    ),

    tf.keras.callbacks.TerminateOnNaN(),
]

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
model = TwoTowerModel(CustomerModel(article_lookup, article_embedding),
                    ArticleModel(article_lookup, article_embedding)
                    )

model.compile(optimizer=tf.keras.optimizers.Adagrad(learning_rate=0.1))

# %%
EPOCHS = 50

with tf.device('/device:GPU:0'):
    history = model.fit(
        train_ds,
        validation_data=test_ds,
        epochs=EPOCHS,
        callbacks=callbacks
        )
# Out:
# Epoch 1/50
# 2026-01-23 10:59:08.486644: I external/local_xla/xla/service/service.cc:163] XLA service 0x7884a8cae800 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2026-01-23 10:59:08.486678: I external/local_xla/xla/service/service.cc:171]   StreamExecutor device (0): NVIDIA GeForce RTX 3080 Laptop GPU, Compute Capability 8.6
# 2026-01-23 10:59:08.493474: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2026-01-23 10:59:08.505980: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:473] Loaded cuDNN version 91701
# I0000 00:00:1769165948.584668   32337 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 55/55 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0222 - factorized_top_k/top_5_categorical_accuracy: 0.0295 - factorized_top_k/top_10_categorical_accuracy: 0.0330 - factorized_top_k/top_50_categorical_accuracy: 0.0471 - factorized_top_k/top_100_categorical_accuracy: 0.0548 - loss: 7050.6559 - regularization_loss: 0.0000e+00 - total_loss: 7050.6559
# Epoch 1: val_factorized_top_k/top_10_categorical_accuracy improved from -inf to 0.00665, saving model to /data/models/checkpoints/pooling_model_best_v2.weights.h5
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# 55/55 [==============================] - 72s 1s/step - factorized_top_k/top_1_categorical_accuracy: 0.0222 - factorized_top_k/top_5_categorical_accuracy: 0.0295 - factorized_top_k/top_10_categorical_accuracy: 0.0330 - factorized_top_k/top_50_categorical_accuracy: 0.0471 - factorized_top_k/top_100_categorical_accuracy: 0.0548 - loss: 7001.7004 - regularization_loss: 0.0000e+00 - total_loss: 7001.7004 - val_factorized_top_k/top_1_categorical_accuracy: 0.0011 - val_factorized_top_k/top_5_categorical_accuracy: 0.0037 - val_factorized_top_k/top_10_categorical_accuracy: 0.0066 - val_factorized_top_k/top_50_categorical_accuracy: 0.0194 - val_factorized_top_k/top_100_categorical_accuracy: 0.0274 - val_loss: 4347.8047 - val_regularization_loss: 0.0000e+00 - val_total_loss: 4347.8047 - lr: 0.1000
# Epoch 2/50
# 55/55 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0091 - factorized_top_k/top_5_categorical_accuracy: 0.0172 - factorized_top_k/top_10_categorical_accuracy: 0.0229 - factorized_top_k/top_50_categorical_accuracy: 0.0466 - factorized_top_k/top_100_categorical_accuracy: 0.0630 - loss: 6611.7235 - regularization_loss: 0.0000e+00 - total_loss: 6611.7235
# Epoch 2: val_factorized_top_k/top_10_categorical_accuracy improved from 0.00665 to 0.01615, saving model to /data/models/checkpoints/pooling_model_best_v2.weights.h5
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# 55/55 [==============================] - 67s 1s/step - factorized_top_k/top_1_categorical_accuracy: 0.0091 - factorized_top_k/top_5_categorical_accuracy: 0.0172 - factorized_top_k/top_10_categorical_accuracy: 0.0229 - factorized_top_k/top_50_categorical_accuracy: 0.0466 - factorized_top_k/top_100_categorical_accuracy: 0.0630 - loss: 6565.6810 - regularization_loss: 0.0000e+00 - total_loss: 6565.6810 - val_factorized_top_k/top_1_categorical_accuracy: 0.0017 - val_factorized_top_k/top_5_categorical_accuracy: 0.0099 - val_factorized_top_k/top_10_categorical_accuracy: 0.0161 - val_factorized_top_k/top_50_categorical_accuracy: 0.0417 - val_factorized_top_k/top_100_categorical_accuracy: 0.0622 - val_loss: 4218.7378 - val_regularization_loss: 0.0000e+00 - val_total_loss: 4218.7378 - lr: 0.1000
# Epoch 3/50
# 55/55 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0180 - factorized_top_k/top_5_categorical_accuracy: 0.0382 - factorized_top_k/top_10_categorical_accuracy: 0.0520 - factorized_top_k/top_50_categorical_accuracy: 0.1070 - factorized_top_k/top_100_categorical_accuracy: 0.1484 - loss: 5881.0571 - regularization_loss: 0.0000e+00 - total_loss: 5881.0571
# Epoch 3: val_factorized_top_k/top_10_categorical_accuracy improved from 0.01615 to 0.03030, saving model to /data/models/checkpoints/pooling_model_best_v2.weights.h5
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# 55/55 [==============================] - 68s 1s/step - factorized_top_k/top_1_categorical_accuracy: 0.0180 - factorized_top_k/top_5_categorical_accuracy: 0.0382 - factorized_top_k/top_10_categorical_accuracy: 0.0520 - factorized_top_k/top_50_categorical_accuracy: 0.1070 - factorized_top_k/top_100_categorical_accuracy: 0.1484 - loss: 5840.9615 - regularization_loss: 0.0000e+00 - total_loss: 5840.9615 - val_factorized_top_k/top_1_categorical_accuracy: 0.0020 - val_factorized_top_k/top_5_categorical_accuracy: 0.0194 - val_factorized_top_k/top_10_categorical_accuracy: 0.0303 - val_factorized_top_k/top_50_categorical_accuracy: 0.0700 - val_factorized_top_k/top_100_categorical_accuracy: 0.0956 - val_loss: 4317.0166 - val_regularization_loss: 0.0000e+00 - val_total_loss: 4317.0166 - lr: 0.1000
# Epoch 4/50
# 55/55 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0322 - factorized_top_k/top_5_categorical_accuracy: 0.0711 - factorized_top_k/top_10_categorical_accuracy: 0.0992 - factorized_top_k/top_50_categorical_accuracy: 0.2098 - factorized_top_k/top_100_categorical_accuracy: 0.2825 - loss: 5123.1605 - regularization_loss: 0.0000e+00 - total_loss: 5123.1605
# Epoch 4: val_factorized_top_k/top_10_categorical_accuracy improved from 0.03030 to 0.04216, saving model to /data/models/checkpoints/pooling_model_best_v2.weights.h5
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# 55/55 [==============================] - 67s 1s/step - factorized_top_k/top_1_categorical_accuracy: 0.0322 - factorized_top_k/top_5_categorical_accuracy: 0.0711 - factorized_top_k/top_10_categorical_accuracy: 0.0992 - factorized_top_k/top_50_categorical_accuracy: 0.2098 - factorized_top_k/top_100_categorical_accuracy: 0.2825 - loss: 5087.5197 - regularization_loss: 0.0000e+00 - total_loss: 5087.5197 - val_factorized_top_k/top_1_categorical_accuracy: 0.0034 - val_factorized_top_k/top_5_categorical_accuracy: 0.0272 - val_factorized_top_k/top_10_categorical_accuracy: 0.0422 - val_factorized_top_k/top_50_categorical_accuracy: 0.0911 - val_factorized_top_k/top_100_categorical_accuracy: 0.1185 - val_loss: 4588.9321 - val_regularization_loss: 0.0000e+00 - val_total_loss: 4588.9321 - lr: 0.1000
# Epoch 5/50
# 55/55 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0405 - factorized_top_k/top_5_categorical_accuracy: 0.1021 - factorized_top_k/top_10_categorical_accuracy: 0.1515 - factorized_top_k/top_50_categorical_accuracy: 0.3191 - factorized_top_k/top_100_categorical_accuracy: 0.4004 - loss: 4502.3570 - regularization_loss: 0.0000e+00 - total_loss: 4502.3570
# Epoch 5: val_factorized_top_k/top_10_categorical_accuracy improved from 0.04216 to 0.04881, saving model to /data/models/checkpoints/pooling_model_best_v2.weights.h5
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# 55/55 [==============================] - 68s 1s/step - factorized_top_k/top_1_categorical_accuracy: 0.0405 - factorized_top_k/top_5_categorical_accuracy: 0.1021 - factorized_top_k/top_10_categorical_accuracy: 0.1515 - factorized_top_k/top_50_categorical_accuracy: 0.3191 - factorized_top_k/top_100_categorical_accuracy: 0.4004 - loss: 4472.9649 - regularization_loss: 0.0000e+00 - total_loss: 4472.9649 - val_factorized_top_k/top_1_categorical_accuracy: 0.0056 - val_factorized_top_k/top_5_categorical_accuracy: 0.0294 - val_factorized_top_k/top_10_categorical_accuracy: 0.0488 - val_factorized_top_k/top_50_categorical_accuracy: 0.1031 - val_factorized_top_k/top_100_categorical_accuracy: 0.1296 - val_loss: 4796.3423 - val_regularization_loss: 0.0000e+00 - val_total_loss: 4796.3423 - lr: 0.1000
# Epoch 6/50
# 55/55 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0461 - factorized_top_k/top_5_categorical_accuracy: 0.1285 - factorized_top_k/top_10_categorical_accuracy: 0.1935 - factorized_top_k/top_50_categorical_accuracy: 0.3906 - factorized_top_k/top_100_categorical_accuracy: 0.4670 - loss: 4055.6132 - regularization_loss: 0.0000e+00 - total_loss: 4055.6132
# Epoch 6: val_factorized_top_k/top_10_categorical_accuracy improved from 0.04881 to 0.05681, saving model to /data/models/checkpoints/pooling_model_best_v2.weights.h5
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# 55/55 [==============================] - 68s 1s/step - factorized_top_k/top_1_categorical_accuracy: 0.0461 - factorized_top_k/top_5_categorical_accuracy: 0.1285 - factorized_top_k/top_10_categorical_accuracy: 0.1935 - factorized_top_k/top_50_categorical_accuracy: 0.3906 - factorized_top_k/top_100_categorical_accuracy: 0.4670 - loss: 4031.2125 - regularization_loss: 0.0000e+00 - total_loss: 4031.2125 - val_factorized_top_k/top_1_categorical_accuracy: 0.0062 - val_factorized_top_k/top_5_categorical_accuracy: 0.0355 - val_factorized_top_k/top_10_categorical_accuracy: 0.0568 - val_factorized_top_k/top_50_categorical_accuracy: 0.1153 - val_factorized_top_k/top_100_categorical_accuracy: 0.1448 - val_loss: 5047.6787 - val_regularization_loss: 0.0000e+00 - val_total_loss: 5047.6787 - lr: 0.1000
# Epoch 7/50
# 55/55 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0539 - factorized_top_k/top_5_categorical_accuracy: 0.1465 - factorized_top_k/top_10_categorical_accuracy: 0.2203 - factorized_top_k/top_50_categorical_accuracy: 0.4296 - factorized_top_k/top_100_categorical_accuracy: 0.5107 - loss: 3757.6592 - regularization_loss: 0.0000e+00 - total_loss: 3757.6592
# Epoch 7: val_factorized_top_k/top_10_categorical_accuracy improved from 0.05681 to 0.05802, saving model to /data/models/checkpoints/pooling_model_best_v2.weights.h5
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# 55/55 [==============================] - 68s 1s/step - factorized_top_k/top_1_categorical_accuracy: 0.0539 - factorized_top_k/top_5_categorical_accuracy: 0.1465 - factorized_top_k/top_10_categorical_accuracy: 0.2203 - factorized_top_k/top_50_categorical_accuracy: 0.4296 - factorized_top_k/top_100_categorical_accuracy: 0.5107 - loss: 3731.8656 - regularization_loss: 0.0000e+00 - total_loss: 3731.8656 - val_factorized_top_k/top_1_categorical_accuracy: 0.0056 - val_factorized_top_k/top_5_categorical_accuracy: 0.0362 - val_factorized_top_k/top_10_categorical_accuracy: 0.0580 - val_factorized_top_k/top_50_categorical_accuracy: 0.1206 - val_factorized_top_k/top_100_categorical_accuracy: 0.1529 - val_loss: 5222.9604 - val_regularization_loss: 0.0000e+00 - val_total_loss: 5222.9604 - lr: 0.1000
# Epoch 8/50
# 55/55 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0513 - factorized_top_k/top_5_categorical_accuracy: 0.1559 - factorized_top_k/top_10_categorical_accuracy: 0.2386 - factorized_top_k/top_50_categorical_accuracy: 0.4664 - factorized_top_k/top_100_categorical_accuracy: 0.5514 - loss: 3521.4089 - regularization_loss: 0.0000e+00 - total_loss: 3521.4089
# Epoch 8: val_factorized_top_k/top_10_categorical_accuracy improved from 0.05802 to 0.06274, saving model to /data/models/checkpoints/pooling_model_best_v2.weights.h5
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# 55/55 [==============================] - 68s 1s/step - factorized_top_k/top_1_categorical_accuracy: 0.0513 - factorized_top_k/top_5_categorical_accuracy: 0.1559 - factorized_top_k/top_10_categorical_accuracy: 0.2386 - factorized_top_k/top_50_categorical_accuracy: 0.4664 - factorized_top_k/top_100_categorical_accuracy: 0.5514 - loss: 3497.5473 - regularization_loss: 0.0000e+00 - total_loss: 3497.5473 - val_factorized_top_k/top_1_categorical_accuracy: 0.0049 - val_factorized_top_k/top_5_categorical_accuracy: 0.0362 - val_factorized_top_k/top_10_categorical_accuracy: 0.0627 - val_factorized_top_k/top_50_categorical_accuracy: 0.1293 - val_factorized_top_k/top_100_categorical_accuracy: 0.1620 - val_loss: 5419.0620 - val_regularization_loss: 0.0000e+00 - val_total_loss: 5419.0620 - lr: 0.1000
# Epoch 9/50
# 55/55 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0625 - factorized_top_k/top_5_categorical_accuracy: 0.1686 - factorized_top_k/top_10_categorical_accuracy: 0.2509 - factorized_top_k/top_50_categorical_accuracy: 0.4914 - factorized_top_k/top_100_categorical_accuracy: 0.5799 - loss: 3356.7773 - regularization_loss: 0.0000e+00 - total_loss: 3356.7773
# Epoch 9: val_factorized_top_k/top_10_categorical_accuracy improved from 0.06274 to 0.06281, saving model to /data/models/checkpoints/pooling_model_best_v2.weights.h5
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# 55/55 [==============================] - 70s 1s/step - factorized_top_k/top_1_categorical_accuracy: 0.0625 - factorized_top_k/top_5_categorical_accuracy: 0.1686 - factorized_top_k/top_10_categorical_accuracy: 0.2509 - factorized_top_k/top_50_categorical_accuracy: 0.4914 - factorized_top_k/top_100_categorical_accuracy: 0.5799 - loss: 3334.0307 - regularization_loss: 0.0000e+00 - total_loss: 3334.0307 - val_factorized_top_k/top_1_categorical_accuracy: 0.0072 - val_factorized_top_k/top_5_categorical_accuracy: 0.0385 - val_factorized_top_k/top_10_categorical_accuracy: 0.0628 - val_factorized_top_k/top_50_categorical_accuracy: 0.1327 - val_factorized_top_k/top_100_categorical_accuracy: 0.1666 - val_loss: 5531.4604 - val_regularization_loss: 0.0000e+00 - val_total_loss: 5531.4604 - lr: 0.1000
# Epoch 10/50
# 55/55 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0550 - factorized_top_k/top_5_categorical_accuracy: 0.1710 - factorized_top_k/top_10_categorical_accuracy: 0.2624 - factorized_top_k/top_50_categorical_accuracy: 0.5220 - factorized_top_k/top_100_categorical_accuracy: 0.6148 - loss: 3205.0050 - regularization_loss: 0.0000e+00 - total_loss: 3205.0050
# Epoch 10: val_factorized_top_k/top_10_categorical_accuracy improved from 0.06281 to 0.06639, saving model to /data/models/checkpoints/pooling_model_best_v2.weights.h5
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# 55/55 [==============================] - 75s 1s/step - factorized_top_k/top_1_categorical_accuracy: 0.0550 - factorized_top_k/top_5_categorical_accuracy: 0.1710 - factorized_top_k/top_10_categorical_accuracy: 0.2624 - factorized_top_k/top_50_categorical_accuracy: 0.5220 - factorized_top_k/top_100_categorical_accuracy: 0.6148 - loss: 3184.3519 - regularization_loss: 0.0000e+00 - total_loss: 3184.3519 - val_factorized_top_k/top_1_categorical_accuracy: 0.0044 - val_factorized_top_k/top_5_categorical_accuracy: 0.0404 - val_factorized_top_k/top_10_categorical_accuracy: 0.0664 - val_factorized_top_k/top_50_categorical_accuracy: 0.1429 - val_factorized_top_k/top_100_categorical_accuracy: 0.1787 - val_loss: 5572.8823 - val_regularization_loss: 0.0000e+00 - val_total_loss: 5572.8823 - lr: 0.1000
# Epoch 11/50
# 55/55 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0547 - factorized_top_k/top_5_categorical_accuracy: 0.1729 - factorized_top_k/top_10_categorical_accuracy: 0.2719 - factorized_top_k/top_50_categorical_accuracy: 0.5427 - factorized_top_k/top_100_categorical_accuracy: 0.6395 - loss: 3079.4229 - regularization_loss: 0.0000e+00 - total_loss: 3079.4229
# Epoch 11: val_factorized_top_k/top_10_categorical_accuracy improved from 0.06639 to 0.06646, saving model to /data/models/checkpoints/pooling_model_best_v2.weights.h5
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# 55/55 [==============================] - 73s 1s/step - factorized_top_k/top_1_categorical_accuracy: 0.0547 - factorized_top_k/top_5_categorical_accuracy: 0.1729 - factorized_top_k/top_10_categorical_accuracy: 0.2719 - factorized_top_k/top_50_categorical_accuracy: 0.5427 - factorized_top_k/top_100_categorical_accuracy: 0.6395 - loss: 3059.1489 - regularization_loss: 0.0000e+00 - total_loss: 3059.1489 - val_factorized_top_k/top_1_categorical_accuracy: 0.0071 - val_factorized_top_k/top_5_categorical_accuracy: 0.0401 - val_factorized_top_k/top_10_categorical_accuracy: 0.0665 - val_factorized_top_k/top_50_categorical_accuracy: 0.1454 - val_factorized_top_k/top_100_categorical_accuracy: 0.1794 - val_loss: 5772.3213 - val_regularization_loss: 0.0000e+00 - val_total_loss: 5772.3213 - lr: 0.1000
# Epoch 12/50
# 55/55 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0576 - factorized_top_k/top_5_categorical_accuracy: 0.1789 - factorized_top_k/top_10_categorical_accuracy: 0.2785 - factorized_top_k/top_50_categorical_accuracy: 0.5573 - factorized_top_k/top_100_categorical_accuracy: 0.6581 - loss: 2985.3410 - regularization_loss: 0.0000e+00 - total_loss: 2985.3410
# Epoch 12: val_factorized_top_k/top_10_categorical_accuracy did not improve from 0.06646
# 55/55 [==============================] - 69s 1s/step - factorized_top_k/top_1_categorical_accuracy: 0.0576 - factorized_top_k/top_5_categorical_accuracy: 0.1789 - factorized_top_k/top_10_categorical_accuracy: 0.2785 - factorized_top_k/top_50_categorical_accuracy: 0.5573 - factorized_top_k/top_100_categorical_accuracy: 0.6581 - loss: 2963.9216 - regularization_loss: 0.0000e+00 - total_loss: 2963.9216 - val_factorized_top_k/top_1_categorical_accuracy: 0.0074 - val_factorized_top_k/top_5_categorical_accuracy: 0.0404 - val_factorized_top_k/top_10_categorical_accuracy: 0.0662 - val_factorized_top_k/top_50_categorical_accuracy: 0.1509 - val_factorized_top_k/top_100_categorical_accuracy: 0.1846 - val_loss: 5887.8926 - val_regularization_loss: 0.0000e+00 - val_total_loss: 5887.8926 - lr: 0.1000
# Epoch 13/50
# 55/55 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0562 - factorized_top_k/top_5_categorical_accuracy: 0.1798 - factorized_top_k/top_10_categorical_accuracy: 0.2832 - factorized_top_k/top_50_categorical_accuracy: 0.5755 - factorized_top_k/top_100_categorical_accuracy: 0.6799 - loss: 2891.2176 - regularization_loss: 0.0000e+00 - total_loss: 2891.2176
# Epoch 13: val_factorized_top_k/top_10_categorical_accuracy improved from 0.06646 to 0.07060, saving model to /data/models/checkpoints/pooling_model_best_v2.weights.h5
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# 55/55 [==============================] - 69s 1s/step - factorized_top_k/top_1_categorical_accuracy: 0.0562 - factorized_top_k/top_5_categorical_accuracy: 0.1798 - factorized_top_k/top_10_categorical_accuracy: 0.2832 - factorized_top_k/top_50_categorical_accuracy: 0.5755 - factorized_top_k/top_100_categorical_accuracy: 0.6799 - loss: 2870.3437 - regularization_loss: 0.0000e+00 - total_loss: 2870.3437 - val_factorized_top_k/top_1_categorical_accuracy: 0.0089 - val_factorized_top_k/top_5_categorical_accuracy: 0.0431 - val_factorized_top_k/top_10_categorical_accuracy: 0.0706 - val_factorized_top_k/top_50_categorical_accuracy: 0.1549 - val_factorized_top_k/top_100_categorical_accuracy: 0.1922 - val_loss: 6019.0659 - val_regularization_loss: 0.0000e+00 - val_total_loss: 6019.0659 - lr: 0.1000
# Epoch 14/50
# 55/55 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0517 - factorized_top_k/top_5_categorical_accuracy: 0.1848 - factorized_top_k/top_10_categorical_accuracy: 0.2917 - factorized_top_k/top_50_categorical_accuracy: 0.5937 - factorized_top_k/top_100_categorical_accuracy: 0.6977 - loss: 2812.0629 - regularization_loss: 0.0000e+00 - total_loss: 2812.0629
# Epoch 14: val_factorized_top_k/top_10_categorical_accuracy did not improve from 0.07060
# 55/55 [==============================] - 69s 1s/step - factorized_top_k/top_1_categorical_accuracy: 0.0517 - factorized_top_k/top_5_categorical_accuracy: 0.1848 - factorized_top_k/top_10_categorical_accuracy: 0.2917 - factorized_top_k/top_50_categorical_accuracy: 0.5937 - factorized_top_k/top_100_categorical_accuracy: 0.6977 - loss: 2793.0656 - regularization_loss: 0.0000e+00 - total_loss: 2793.0656 - val_factorized_top_k/top_1_categorical_accuracy: 0.0051 - val_factorized_top_k/top_5_categorical_accuracy: 0.0390 - val_factorized_top_k/top_10_categorical_accuracy: 0.0680 - val_factorized_top_k/top_50_categorical_accuracy: 0.1561 - val_factorized_top_k/top_100_categorical_accuracy: 0.1942 - val_loss: 6033.6035 - val_regularization_loss: 0.0000e+00 - val_total_loss: 6033.6035 - lr: 0.1000
# Epoch 15/50
# 55/55 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0542 - factorized_top_k/top_5_categorical_accuracy: 0.1856 - factorized_top_k/top_10_categorical_accuracy: 0.2944 - factorized_top_k/top_50_categorical_accuracy: 0.6071 - factorized_top_k/top_100_categorical_accuracy: 0.7118 - loss: 2742.9867 - regularization_loss: 0.0000e+00 - total_loss: 2742.9867
# Epoch 15: val_factorized_top_k/top_10_categorical_accuracy improved from 0.07060 to 0.07139, saving model to /data/models/checkpoints/pooling_model_best_v2.weights.h5
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# 55/55 [==============================] - 71s 1s/step - factorized_top_k/top_1_categorical_accuracy: 0.0542 - factorized_top_k/top_5_categorical_accuracy: 0.1856 - factorized_top_k/top_10_categorical_accuracy: 0.2944 - factorized_top_k/top_50_categorical_accuracy: 0.6071 - factorized_top_k/top_100_categorical_accuracy: 0.7118 - loss: 2724.3282 - regularization_loss: 0.0000e+00 - total_loss: 2724.3282 - val_factorized_top_k/top_1_categorical_accuracy: 0.0055 - val_factorized_top_k/top_5_categorical_accuracy: 0.0417 - val_factorized_top_k/top_10_categorical_accuracy: 0.0714 - val_factorized_top_k/top_50_categorical_accuracy: 0.1574 - val_factorized_top_k/top_100_categorical_accuracy: 0.1961 - val_loss: 6127.8906 - val_regularization_loss: 0.0000e+00 - val_total_loss: 6127.8906 - lr: 0.1000
# Epoch 16/50
# 55/55 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0546 - factorized_top_k/top_5_categorical_accuracy: 0.1867 - factorized_top_k/top_10_categorical_accuracy: 0.2959 - factorized_top_k/top_50_categorical_accuracy: 0.6132 - factorized_top_k/top_100_categorical_accuracy: 0.7231 - loss: 2685.5124 - regularization_loss: 0.0000e+00 - total_loss: 2685.5124
# Epoch 16: val_factorized_top_k/top_10_categorical_accuracy improved from 0.07139 to 0.07389, saving model to /data/models/checkpoints/pooling_model_best_v2.weights.h5
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# 55/55 [==============================] - 71s 1s/step - factorized_top_k/top_1_categorical_accuracy: 0.0546 - factorized_top_k/top_5_categorical_accuracy: 0.1867 - factorized_top_k/top_10_categorical_accuracy: 0.2959 - factorized_top_k/top_50_categorical_accuracy: 0.6132 - factorized_top_k/top_100_categorical_accuracy: 0.7231 - loss: 2667.9152 - regularization_loss: 0.0000e+00 - total_loss: 2667.9152 - val_factorized_top_k/top_1_categorical_accuracy: 0.0043 - val_factorized_top_k/top_5_categorical_accuracy: 0.0414 - val_factorized_top_k/top_10_categorical_accuracy: 0.0739 - val_factorized_top_k/top_50_categorical_accuracy: 0.1617 - val_factorized_top_k/top_100_categorical_accuracy: 0.1989 - val_loss: 6204.6958 - val_regularization_loss: 0.0000e+00 - val_total_loss: 6204.6958 - lr: 0.1000
# Epoch 17/50
# 55/55 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0500 - factorized_top_k/top_5_categorical_accuracy: 0.1895 - factorized_top_k/top_10_categorical_accuracy: 0.3017 - factorized_top_k/top_50_categorical_accuracy: 0.6309 - factorized_top_k/top_100_categorical_accuracy: 0.7390 - loss: 2625.7626 - regularization_loss: 0.0000e+00 - total_loss: 2625.7626
# Epoch 17: val_factorized_top_k/top_10_categorical_accuracy did not improve from 0.07389
# 55/55 [==============================] - 69s 1s/step - factorized_top_k/top_1_categorical_accuracy: 0.0500 - factorized_top_k/top_5_categorical_accuracy: 0.1895 - factorized_top_k/top_10_categorical_accuracy: 0.3017 - factorized_top_k/top_50_categorical_accuracy: 0.6309 - factorized_top_k/top_100_categorical_accuracy: 0.7390 - loss: 2607.9358 - regularization_loss: 0.0000e+00 - total_loss: 2607.9358 - val_factorized_top_k/top_1_categorical_accuracy: 0.0066 - val_factorized_top_k/top_5_categorical_accuracy: 0.0420 - val_factorized_top_k/top_10_categorical_accuracy: 0.0734 - val_factorized_top_k/top_50_categorical_accuracy: 0.1624 - val_factorized_top_k/top_100_categorical_accuracy: 0.2019 - val_loss: 6300.4224 - val_regularization_loss: 0.0000e+00 - val_total_loss: 6300.4224 - lr: 0.1000
# Epoch 18/50
# 55/55 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0491 - factorized_top_k/top_5_categorical_accuracy: 0.1904 - factorized_top_k/top_10_categorical_accuracy: 0.3047 - factorized_top_k/top_50_categorical_accuracy: 0.6389 - factorized_top_k/top_100_categorical_accuracy: 0.7483 - loss: 2575.4134 - regularization_loss: 0.0000e+00 - total_loss: 2575.4134
# Epoch 18: val_factorized_top_k/top_10_categorical_accuracy did not improve from 0.07389
# 55/55 [==============================] - 71s 1s/step - factorized_top_k/top_1_categorical_accuracy: 0.0491 - factorized_top_k/top_5_categorical_accuracy: 0.1904 - factorized_top_k/top_10_categorical_accuracy: 0.3047 - factorized_top_k/top_50_categorical_accuracy: 0.6389 - factorized_top_k/top_100_categorical_accuracy: 0.7483 - loss: 2558.7655 - regularization_loss: 0.0000e+00 - total_loss: 2558.7655 - val_factorized_top_k/top_1_categorical_accuracy: 0.0078 - val_factorized_top_k/top_5_categorical_accuracy: 0.0442 - val_factorized_top_k/top_10_categorical_accuracy: 0.0738 - val_factorized_top_k/top_50_categorical_accuracy: 0.1659 - val_factorized_top_k/top_100_categorical_accuracy: 0.2034 - val_loss: 6357.3105 - val_regularization_loss: 0.0000e+00 - val_total_loss: 6357.3105 - lr: 0.1000
# Epoch 19/50
# 55/55 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0495 - factorized_top_k/top_5_categorical_accuracy: 0.1909 - factorized_top_k/top_10_categorical_accuracy: 0.3068 - factorized_top_k/top_50_categorical_accuracy: 0.6472 - factorized_top_k/top_100_categorical_accuracy: 0.7579 - loss: 2531.0056 - regularization_loss: 0.0000e+00 - total_loss: 2531.0056
# Epoch 19: val_factorized_top_k/top_10_categorical_accuracy improved from 0.07389 to 0.07568, saving model to /data/models/checkpoints/pooling_model_best_v2.weights.h5
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# 55/55 [==============================] - 76s 1s/step - factorized_top_k/top_1_categorical_accuracy: 0.0495 - factorized_top_k/top_5_categorical_accuracy: 0.1909 - factorized_top_k/top_10_categorical_accuracy: 0.3068 - factorized_top_k/top_50_categorical_accuracy: 0.6472 - factorized_top_k/top_100_categorical_accuracy: 0.7579 - loss: 2513.9023 - regularization_loss: 0.0000e+00 - total_loss: 2513.9023 - val_factorized_top_k/top_1_categorical_accuracy: 0.0086 - val_factorized_top_k/top_5_categorical_accuracy: 0.0449 - val_factorized_top_k/top_10_categorical_accuracy: 0.0757 - val_factorized_top_k/top_50_categorical_accuracy: 0.1694 - val_factorized_top_k/top_100_categorical_accuracy: 0.2059 - val_loss: 6435.5488 - val_regularization_loss: 0.0000e+00 - val_total_loss: 6435.5488 - lr: 0.1000
# Epoch 20/50
# 55/55 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0505 - factorized_top_k/top_5_categorical_accuracy: 0.1909 - factorized_top_k/top_10_categorical_accuracy: 0.3102 - factorized_top_k/top_50_categorical_accuracy: 0.6539 - factorized_top_k/top_100_categorical_accuracy: 0.7664 - loss: 2489.8750 - regularization_loss: 0.0000e+00 - total_loss: 2489.8750
# Epoch 20: val_factorized_top_k/top_10_categorical_accuracy did not improve from 0.07568
# 55/55 [==============================] - 73s 1s/step - factorized_top_k/top_1_categorical_accuracy: 0.0505 - factorized_top_k/top_5_categorical_accuracy: 0.1909 - factorized_top_k/top_10_categorical_accuracy: 0.3102 - factorized_top_k/top_50_categorical_accuracy: 0.6539 - factorized_top_k/top_100_categorical_accuracy: 0.7664 - loss: 2474.3642 - regularization_loss: 0.0000e+00 - total_loss: 2474.3642 - val_factorized_top_k/top_1_categorical_accuracy: 0.0065 - val_factorized_top_k/top_5_categorical_accuracy: 0.0447 - val_factorized_top_k/top_10_categorical_accuracy: 0.0743 - val_factorized_top_k/top_50_categorical_accuracy: 0.1668 - val_factorized_top_k/top_100_categorical_accuracy: 0.2075 - val_loss: 6472.0786 - val_regularization_loss: 0.0000e+00 - val_total_loss: 6472.0786 - lr: 0.1000
# Epoch 21/50
# 55/55 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0474 - factorized_top_k/top_5_categorical_accuracy: 0.1940 - factorized_top_k/top_10_categorical_accuracy: 0.3114 - factorized_top_k/top_50_categorical_accuracy: 0.6633 - factorized_top_k/top_100_categorical_accuracy: 0.7756 - loss: 2446.0461 - regularization_loss: 0.0000e+00 - total_loss: 2446.0461
# Epoch 21: val_factorized_top_k/top_10_categorical_accuracy did not improve from 0.07568
# 55/55 [==============================] - 73s 1s/step - factorized_top_k/top_1_categorical_accuracy: 0.0474 - factorized_top_k/top_5_categorical_accuracy: 0.1940 - factorized_top_k/top_10_categorical_accuracy: 0.3114 - factorized_top_k/top_50_categorical_accuracy: 0.6633 - factorized_top_k/top_100_categorical_accuracy: 0.7756 - loss: 2428.5771 - regularization_loss: 0.0000e+00 - total_loss: 2428.5771 - val_factorized_top_k/top_1_categorical_accuracy: 0.0059 - val_factorized_top_k/top_5_categorical_accuracy: 0.0429 - val_factorized_top_k/top_10_categorical_accuracy: 0.0736 - val_factorized_top_k/top_50_categorical_accuracy: 0.1676 - val_factorized_top_k/top_100_categorical_accuracy: 0.2062 - val_loss: 6575.3110 - val_regularization_loss: 0.0000e+00 - val_total_loss: 6575.3110 - lr: 0.1000
# Epoch 22/50
# ...
# Epoch 25/50
# 55/55 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0496 - factorized_top_k/top_5_categorical_accuracy: 0.1974 - factorized_top_k/top_10_categorical_accuracy: 0.3189 - factorized_top_k/top_50_categorical_accuracy: 0.6856 - factorized_top_k/top_100_categorical_accuracy: 0.8018 - loss: 2327.1672 - regularization_loss: 0.0000e+00 - total_loss: 2327.1672
# Epoch 25: val_factorized_top_k/top_10_categorical_accuracy improved from 0.07660 to 0.07768, saving model to /data/models/checkpoints/pooling_model_best_v2.weights.h5
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# 55/55 [==============================] - 70s 1s/step - factorized_top_k/top_1_categorical_accuracy: 0.0496 - factorized_top_k/top_5_categorical_accuracy: 0.1974 - factorized_top_k/top_10_categorical_accuracy: 0.3189 - factorized_top_k/top_50_categorical_accuracy: 0.6856 - factorized_top_k/top_100_categorical_accuracy: 0.8018 - loss: 2311.1869 - regularization_loss: 0.0000e+00 - total_loss: 2311.1869 - val_factorized_top_k/top_1_categorical_accuracy: 0.0089 - val_factorized_top_k/top_5_categorical_accuracy: 0.0454 - val_factorized_top_k/top_10_categorical_accuracy: 0.0777 - val_factorized_top_k/top_50_categorical_accuracy: 0.1730 - val_factorized_top_k/top_100_categorical_accuracy: 0.2131 - val_loss: 6753.1040 - val_regularization_loss: 0.0000e+00 - val_total_loss: 6753.1040 - lr: 0.1000
# Epoch 26/50
# 55/55 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0490 - factorized_top_k/top_5_categorical_accuracy: 0.1990 - factorized_top_k/top_10_categorical_accuracy: 0.3212 - factorized_top_k/top_50_categorical_accuracy: 0.6917 - factorized_top_k/top_100_categorical_accuracy: 0.8081 - loss: 2294.2291 - regularization_loss: 0.0000e+00 - total_loss: 2294.2291
# Epoch 26: val_factorized_top_k/top_10_categorical_accuracy improved from 0.07768 to 0.07789, saving model to /data/models/checkpoints/pooling_model_best_v2.weights.h5
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# 55/55 [==============================] - 74s 1s/step - factorized_top_k/top_1_categorical_accuracy: 0.0490 - factorized_top_k/top_5_categorical_accuracy: 0.1990 - factorized_top_k/top_10_categorical_accuracy: 0.3212 - factorized_top_k/top_50_categorical_accuracy: 0.6917 - factorized_top_k/top_100_categorical_accuracy: 0.8081 - loss: 2279.4035 - regularization_loss: 0.0000e+00 - total_loss: 2279.4035 - val_factorized_top_k/top_1_categorical_accuracy: 0.0079 - val_factorized_top_k/top_5_categorical_accuracy: 0.0453 - val_factorized_top_k/top_10_categorical_accuracy: 0.0779 - val_factorized_top_k/top_50_categorical_accuracy: 0.1739 - val_factorized_top_k/top_100_categorical_accuracy: 0.2132 - val_loss: 6946.7412 - val_regularization_loss: 0.0000e+00 - val_total_loss: 6946.7412 - lr: 0.1000
# Epoch 27/50
# 55/55 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0484 - factorized_top_k/top_5_categorical_accuracy: 0.2006 - factorized_top_k/top_10_categorical_accuracy: 0.3225 - factorized_top_k/top_50_categorical_accuracy: 0.6941 - factorized_top_k/top_100_categorical_accuracy: 0.8114 - loss: 2268.6522 - regularization_loss: 0.0000e+00 - total_loss: 2268.6522
# Epoch 27: val_factorized_top_k/top_10_categorical_accuracy did not improve from 0.07789
# 55/55 [==============================] - 73s 1s/step - factorized_top_k/top_1_categorical_accuracy: 0.0484 - factorized_top_k/top_5_categorical_accuracy: 0.2006 - factorized_top_k/top_10_categorical_accuracy: 0.3225 - factorized_top_k/top_50_categorical_accuracy: 0.6941 - factorized_top_k/top_100_categorical_accuracy: 0.8114 - loss: 2252.8690 - regularization_loss: 0.0000e+00 - total_loss: 2252.8690 - val_factorized_top_k/top_1_categorical_accuracy: 0.0071 - val_factorized_top_k/top_5_categorical_accuracy: 0.0442 - val_factorized_top_k/top_10_categorical_accuracy: 0.0767 - val_factorized_top_k/top_50_categorical_accuracy: 0.1727 - val_factorized_top_k/top_100_categorical_accuracy: 0.2129 - val_loss: 6945.9731 - val_regularization_loss: 0.0000e+00 - val_total_loss: 6945.9731 - lr: 0.1000
# Epoch 28/50
# 55/55 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0462 - factorized_top_k/top_5_categorical_accuracy: 0.2003 - factorized_top_k/top_10_categorical_accuracy: 0.3244 - factorized_top_k/top_50_categorical_accuracy: 0.7024 - factorized_top_k/top_100_categorical_accuracy: 0.8185 - loss: 2242.6498 - regularization_loss: 0.0000e+00 - total_loss: 2242.6498
# Epoch 28: val_factorized_top_k/top_10_categorical_accuracy did not improve from 0.07789
# 55/55 [==============================] - 72s 1s/step - factorized_top_k/top_1_categorical_accuracy: 0.0462 - factorized_top_k/top_5_categorical_accuracy: 0.2003 - factorized_top_k/top_10_categorical_accuracy: 0.3244 - factorized_top_k/top_50_categorical_accuracy: 0.7024 - factorized_top_k/top_100_categorical_accuracy: 0.8185 - loss: 2228.9038 - regularization_loss: 0.0000e+00 - total_loss: 2228.9038 - val_factorized_top_k/top_1_categorical_accuracy: 0.0069 - val_factorized_top_k/top_5_categorical_accuracy: 0.0430 - val_factorized_top_k/top_10_categorical_accuracy: 0.0760 - val_factorized_top_k/top_50_categorical_accuracy: 0.1728 - val_factorized_top_k/top_100_categorical_accuracy: 0.2127 - val_loss: 7019.8408 - val_regularization_loss: 0.0000e+00 - val_total_loss: 7019.8408 - lr: 0.1000
# Epoch 29/50
# 55/55 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0475 - factorized_top_k/top_5_categorical_accuracy: 0.2006 - factorized_top_k/top_10_categorical_accuracy: 0.3246 - factorized_top_k/top_50_categorical_accuracy: 0.7052 - factorized_top_k/top_100_categorical_accuracy: 0.8219 - loss: 2223.5675 - regularization_loss: 0.0000e+00 - total_loss: 2223.5675
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.010000000707805157.
#
# Epoch 29: val_factorized_top_k/top_10_categorical_accuracy did not improve from 0.07789
# 55/55 [==============================] - 68s 1s/step - factorized_top_k/top_1_categorical_accuracy: 0.0475 - factorized_top_k/top_5_categorical_accuracy: 0.2006 - factorized_top_k/top_10_categorical_accuracy: 0.3246 - factorized_top_k/top_50_categorical_accuracy: 0.7052 - factorized_top_k/top_100_categorical_accuracy: 0.8219 - loss: 2209.1061 - regularization_loss: 0.0000e+00 - total_loss: 2209.1061 - val_factorized_top_k/top_1_categorical_accuracy: 0.0048 - val_factorized_top_k/top_5_categorical_accuracy: 0.0442 - val_factorized_top_k/top_10_categorical_accuracy: 0.0735 - val_factorized_top_k/top_50_categorical_accuracy: 0.1736 - val_factorized_top_k/top_100_categorical_accuracy: 0.2147 - val_loss: 6973.8364 - val_regularization_loss: 0.0000e+00 - val_total_loss: 6973.8364 - lr: 0.1000
# Epoch 30/50
# 55/55 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0395 - factorized_top_k/top_5_categorical_accuracy: 0.2055 - factorized_top_k/top_10_categorical_accuracy: 0.3433 - factorized_top_k/top_50_categorical_accuracy: 0.7394 - factorized_top_k/top_100_categorical_accuracy: 0.8475 - loss: 2033.1858 - regularization_loss: 0.0000e+00 - total_loss: 2033.1858
# Epoch 30: val_factorized_top_k/top_10_categorical_accuracy did not improve from 0.07789
# 55/55 [==============================] - 69s 1s/step - factorized_top_k/top_1_categorical_accuracy: 0.0395 - factorized_top_k/top_5_categorical_accuracy: 0.2055 - factorized_top_k/top_10_categorical_accuracy: 0.3433 - factorized_top_k/top_50_categorical_accuracy: 0.7394 - factorized_top_k/top_100_categorical_accuracy: 0.8475 - loss: 2017.0995 - regularization_loss: 0.0000e+00 - total_loss: 2017.0995 - val_factorized_top_k/top_1_categorical_accuracy: 0.0081 - val_factorized_top_k/top_5_categorical_accuracy: 0.0467 - val_factorized_top_k/top_10_categorical_accuracy: 0.0752 - val_factorized_top_k/top_50_categorical_accuracy: 0.1766 - val_factorized_top_k/top_100_categorical_accuracy: 0.2163 - val_loss: 7201.8286 - val_regularization_loss: 0.0000e+00 - val_total_loss: 7201.8286 - lr: 0.0100
# Epoch 31/50
# 55/55 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0389 - factorized_top_k/top_5_categorical_accuracy: 0.2070 - factorized_top_k/top_10_categorical_accuracy: 0.3453 - factorized_top_k/top_50_categorical_accuracy: 0.7445 - factorized_top_k/top_100_categorical_accuracy: 0.8514 - loss: 2001.9515 - regularization_loss: 0.0000e+00 - total_loss: 2001.9515
# Epoch 31: val_factorized_top_k/top_10_categorical_accuracy did not improve from 0.07789
# 55/55 [==============================] - 66s 1s/step - factorized_top_k/top_1_categorical_accuracy: 0.0389 - factorized_top_k/top_5_categorical_accuracy: 0.2070 - factorized_top_k/top_10_categorical_accuracy: 0.3453 - factorized_top_k/top_50_categorical_accuracy: 0.7445 - factorized_top_k/top_100_categorical_accuracy: 0.8514 - loss: 1987.2754 - regularization_loss: 0.0000e+00 - total_loss: 1987.2754 - val_factorized_top_k/top_1_categorical_accuracy: 0.0051 - val_factorized_top_k/top_5_categorical_accuracy: 0.0454 - val_factorized_top_k/top_10_categorical_accuracy: 0.0759 - val_factorized_top_k/top_50_categorical_accuracy: 0.1780 - val_factorized_top_k/top_100_categorical_accuracy: 0.2181 - val_loss: 7320.2246 - val_regularization_loss: 0.0000e+00 - val_total_loss: 7320.2246 - lr: 0.0100
# Epoch 32/50
# 55/55 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0368 - factorized_top_k/top_5_categorical_accuracy: 0.2055 - factorized_top_k/top_10_categorical_accuracy: 0.3467 - factorized_top_k/top_50_categorical_accuracy: 0.7481 - factorized_top_k/top_100_categorical_accuracy: 0.8533 - loss: 1979.8789 - regularization_loss: 0.0000e+00 - total_loss: 1979.8789
# Epoch 32: ReduceLROnPlateau reducing learning rate to 0.0010000000474974513.
#
# Epoch 32: val_factorized_top_k/top_10_categorical_accuracy did not improve from 0.07789
# 55/55 [==============================] - 67s 1s/step - factorized_top_k/top_1_categorical_accuracy: 0.0368 - factorized_top_k/top_5_categorical_accuracy: 0.2055 - factorized_top_k/top_10_categorical_accuracy: 0.3467 - factorized_top_k/top_50_categorical_accuracy: 0.7481 - factorized_top_k/top_100_categorical_accuracy: 0.8533 - loss: 1965.1796 - regularization_loss: 0.0000e+00 - total_loss: 1965.1796 - val_factorized_top_k/top_1_categorical_accuracy: 0.0074 - val_factorized_top_k/top_5_categorical_accuracy: 0.0466 - val_factorized_top_k/top_10_categorical_accuracy: 0.0770 - val_factorized_top_k/top_50_categorical_accuracy: 0.1779 - val_factorized_top_k/top_100_categorical_accuracy: 0.2187 - val_loss: 7415.1851 - val_regularization_loss: 0.0000e+00 - val_total_loss: 7415.1851 - lr: 0.0100
# Epoch 33/50
# 55/55 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0323 - factorized_top_k/top_5_categorical_accuracy: 0.2047 - factorized_top_k/top_10_categorical_accuracy: 0.3479 - factorized_top_k/top_50_categorical_accuracy: 0.7523 - factorized_top_k/top_100_categorical_accuracy: 0.8568 - loss: 1947.6422 - regularization_loss: 0.0000e+00 - total_loss: 1947.6422
# Epoch 33: val_factorized_top_k/top_10_categorical_accuracy did not improve from 0.07789
# 55/55 [==============================] - 67s 1s/step - factorized_top_k/top_1_categorical_accuracy: 0.0323 - factorized_top_k/top_5_categorical_accuracy: 0.2047 - factorized_top_k/top_10_categorical_accuracy: 0.3479 - factorized_top_k/top_50_categorical_accuracy: 0.7523 - factorized_top_k/top_100_categorical_accuracy: 0.8568 - loss: 1934.8638 - regularization_loss: 0.0000e+00 - total_loss: 1934.8638 - val_factorized_top_k/top_1_categorical_accuracy: 0.0058 - val_factorized_top_k/top_5_categorical_accuracy: 0.0459 - val_factorized_top_k/top_10_categorical_accuracy: 0.0764 - val_factorized_top_k/top_50_categorical_accuracy: 0.1783 - val_factorized_top_k/top_100_categorical_accuracy: 0.2184 - val_loss: 7425.7910 - val_regularization_loss: 0.0000e+00 - val_total_loss: 7425.7910 - lr: 0.0010
# Epoch 34/50
# 55/55 [==============================] - ETA: 0s - factorized_top_k/top_1_categorical_accuracy: 0.0345 - factorized_top_k/top_5_categorical_accuracy: 0.2057 - factorized_top_k/top_10_categorical_accuracy: 0.3488 - factorized_top_k/top_50_categorical_accuracy: 0.7527 - factorized_top_k/top_100_categorical_accuracy: 0.8570 - loss: 1946.5799 - regularization_loss: 0.0000e+00 - total_loss: 1946.5799
# Epoch 34: val_factorized_top_k/top_10_categorical_accuracy did not improve from 0.07789
# 55/55 [==============================] - 68s 1s/step - factorized_top_k/top_1_categorical_accuracy: 0.0345 - factorized_top_k/top_5_categorical_accuracy: 0.2057 - factorized_top_k/top_10_categorical_accuracy: 0.3488 - factorized_top_k/top_50_categorical_accuracy: 0.7527 - factorized_top_k/top_100_categorical_accuracy: 0.8570 - loss: 1931.8147 - regularization_loss: 0.0000e+00 - total_loss: 1931.8147 - val_factorized_top_k/top_1_categorical_accuracy: 0.0063 - val_factorized_top_k/top_5_categorical_accuracy: 0.0455 - val_factorized_top_k/top_10_categorical_accuracy: 0.0764 - val_factorized_top_k/top_50_categorical_accuracy: 0.1784 - val_factorized_top_k/top_100_categorical_accuracy: 0.2184 - val_loss: 7437.4150 - val_regularization_loss: 0.0000e+00 - val_total_loss: 7437.4150 - lr: 0.0010
# Epoch 34: early stopping
# Restoring model weights from the end of the best epoch: 26.
